# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import math
import random

# %%
random.seed(2)
sample_size = 10; sample_min = -2; sample_max = 2;

# %%
def gaussian(x, mu, sigma):
    return np.exp(-1.0 * np.power((x-mu), 2) / (2 * np.power(sigma, 2))) / np.sqrt(2 * np.pi * np.power(sigma, 2))

# %%
# Initialise: Randomly initialising the model's parameters.
sampled_points = np.random.uniform(low=sample_min, high=sample_max, size=(sample_size))
mu = np.random.rand(2)
sigma = np.random.rand(2)
prior = 0.5 * np.ones((2))
H = np.zeros((sample_size, 2))

# %%
# E-step: Using the current model parameters to carry out soft assignments.
def e_step():
    P_Oi_m0 = gaussian(sampled_points, mu[0], sigma[0])
    P_Oi_m1 = gaussian(sampled_points, mu[1], sigma[1])
    H[:, 0] = (P_Oi_m0 * prior[0]) / (P_Oi_m0 * prior[0] + P_Oi_m1 * prior[1])
    H[:, 1] = (P_Oi_m1 * prior[1]) / (P_Oi_m0 * prior[0] + P_Oi_m1 * prior[1])

# %%
# M-step: Re-estimating the model parameters.
def m_step():
    mu[0] = np.sum(H[:, 0] * sampled_points) / np.sum(H[:, 0])
    mu[1] = np.sum(H[:, 1] * sampled_points) / np.sum(H[:, 1])
    sigma[0] = np.sqrt(np.sum(H[:, 0] * np.power(sampled_points-mu[0],2)) / np.sum(H[:, 0]))
    sigma[1] = np.sqrt(np.sum(H[:, 1] * np.power(sampled_points-mu[1],2)) / np.sum(H[:, 1]))  
    prior[0] = np.mean(H[:, 0])
    prior[1] = np.mean(H[:, 1])

# %%
# Iterate.
iteration = 1
curr_diff = 1
# while curr_diff > diff_thresold:
while iteration <= 20:
    print "\nIteration no:", iteration
    x_0 = np.linspace(np.min(sampled_points), np.max(sampled_points), 100)
    x_1 = np.linspace(np.min(sampled_points), np.max(sampled_points), 100)
    plt.scatter(sampled_points, np.zeros(sample_size), color='red')
    plt.plot(x_0,mlab.normpdf(x_0, mu[0], sigma[0]), color='green')
    plt.plot(x_1,mlab.normpdf(x_1, mu[1], sigma[1]), color='blue')    
    plt.show()

    e_step()
    m_step()
    
    print "Mean: ", mu[0], ":", mu[1]
    print "Standard Deviation: ", sigma[0], ":", sigma[1]
    print "Prior Probabilities: ", prior[0], ":", prior[1]
    iteration += 1
# Out:
# Iteration no: 1
# Mean:  0.122506727551 : 0.786006160002
# Standard Deviation:  1.10762413888 : 0.876295166459
# Prior Probabilities:  0.473538823873 : 0.526461176127
#
# Iteration no: 2
# Mean:  0.0712030907082 : 0.826623080564
# Standard Deviation:  1.14092242323 : 0.802394486027
# Prior Probabilities:  0.469685295875 : 0.530314704125
#
# Iteration no: 3
# Mean:  0.0117511475008 : 0.870117326816
# Standard Deviation:  1.14234170548 : 0.75583566356
# Prior Probabilities:  0.464025630664 : 0.535974369336
#
# Iteration no: 4
# Mean:  -0.0426535938936 : 0.907415023879
# Standard Deviation:  1.12679190245 : 0.730207998704
# Prior Probabilities:  0.458494888276 : 0.541505111724
#
# Iteration no: 5
# Mean:  -0.0883738318666 : 0.937953280792
# Standard Deviation:  1.10580481835 : 0.714269739001
# Prior Probabilities:  0.454182546601 : 0.545817453399
#
# Iteration no: 6
# Mean:  -0.125722086911 : 0.963205071674
# Standard Deviation:  1.08458831331 : 0.702116287118
# Prior Probabilities:  0.451262188367 : 0.548737811633
#
# Iteration no: 7
# Mean:  -0.155942557034 : 0.984763067287
# Standard Deviation:  1.06465898486 : 0.691635022293
# Prior Probabilities:  0.449677495431 : 0.550322504569
#
# Iteration no: 8
# Mean:  -0.180235543708 : 1.00390770998
# Standard Deviation:  1.04628155596 : 0.681987049558
# Prior Probabilities:  0.449349594487 : 0.550650405513
#
# Iteration no: 9
# Mean:  -0.199578091066 : 1.02161600292
# Standard Deviation:  1.02936698687 : 0.672694436045
# Prior Probabilities:  0.450217198484 : 0.549782801516
#
# Iteration no: 10
# Mean:  -0.214736231644 : 1.0386612869
# Standard Deviation:  1.01372167913 : 0.663383772567
# Prior Probabilities:  0.452249074532 : 0.547750925468
#
# Iteration no: 11
# Mean:  -0.226304896319 : 1.05570683533
# Standard Deviation:  0.999113054842 : 0.653698661788
# Prior Probabilities:  0.455450914993 : 0.544549085007
#
# Iteration no: 12
# Mean:  -0.234743381434 : 1.07338294022
# Standard Deviation:  0.985285660726 : 0.643247202954
# Prior Probabilities:  0.459871123411 : 0.540128876589
#
# Iteration no: 13
# Mean:  -0.240401647544 : 1.09235658684
# Standard Deviation:  0.971961093778 : 0.631547923316
# Prior Probabilities:  0.465608203884 : 0.534391796116
#
# Iteration no: 14
# Mean:  -0.243537515086 : 1.11340581966
# Standard Deviation:  0.958830276445 : 0.617955119199
# Prior Probabilities:  0.472821807745 : 0.527178192255
#
# Iteration no: 15
# Mean:  -0.244325216288 : 1.13751173242
# Standard Deviation:  0.945540704733 : 0.601539930067
# Prior Probabilities:  0.481748815533 : 0.518251184467
#
# Iteration no: 16
# Mean:  -0.24285530517 : 1.16597998133
# Standard Deviation:  0.931681292196 : 0.580886338314
# Prior Probabilities:  0.492723719277 : 0.507276280723
#
# Iteration no: 17
# Mean:  -0.23912653825 : 1.20058732011
# Standard Deviation:  0.91677451866 : 0.553731133111
# Prior Probabilities:  0.506193572257 : 0.493806427743
#
# Iteration no: 18
# Mean:  -0.233038311845 : 1.24365129671
# Standard Deviation:  0.900315249921 : 0.516363544037
# Prior Probabilities:  0.522681187109 : 0.477318812891
#
# Iteration no: 19
# Mean:  -0.224428334096 : 1.29745435809
# Standard Deviation:  0.882007519611 : 0.463023804316
# Prior Probabilities:  0.54251286463 : 0.45748713537
#
# Iteration no: 20
# Mean:  -0.213213420817 : 1.36077122168
# Standard Deviation:  0.862698616418 : 0.388444374229
# Prior Probabilities:  0.564781751078 : 0.435218248922
